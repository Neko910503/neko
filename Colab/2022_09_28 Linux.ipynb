# %%
print("Hello, world")
# Out:
# Hello, world

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
# %cd '/content/drive/MyDrive/DataScience_111'
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/DataScience_111'
# /content

# %%
# !git clone https://github.com/leriomaggio/python-in-a-notebook
# Out:
# Cloning into 'python-in-a-notebook'...
# remote: Enumerating objects: 154, done.
# remote: Total 154 (delta 0), reused 0 (delta 0), pack-reused 154
# Receiving objects: 100% (154/154), 192.92 KiB | 4.49 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
# !git clone https://github.com/Pierian-Data/Complete-Python-3-Bootcamp
# Out:
# Cloning into 'Complete-Python-3-Bootcamp'...
# remote: Enumerating objects: 780, done.
# remote: Total 780 (delta 0), reused 0 (delta 0), pack-reused 780
# Receiving objects: 100% (780/780), 36.25 MiB | 10.67 MiB/s, done.
# Resolving deltas: 100% (325/325), done.

# %%
message = "Hello world"
name = "HWCHIU"
print(message + "," + name + ". Do you enjoy python?" )
# Out:
# Hello world,HWCHIU. Do you enjoy python?

# %%
first_name = 'eric'

print(first_name)
print(first_name.title())
print(first_name.upper())
print(first_name.upper() + '\n'*10 + first_name.upper())
# Out:
# eric
# Eric
# ERIC
# ERIC
#
#
#
#
#
#
#
#
#
# ERIC

# %%
Z = complex(1,2)
j = complex(0,1)
print(Z*j)
# Out:
# (-2+1j)

# %%
import random, string

print(random.choice(string.ascii_letters))
print(random.choice(string.ascii_uppercase)+random.choice(string.ascii_lowercase))
print(random.choice(string.ascii_letters)+random.choice(string.ascii_letters)+random.choice(string.ascii_letters)+random.choice(string.ascii_letters)+random.choice(string.ascii_letters))
print(chr(random.randint(32,126))+chr(random.randint(32,126))+chr(random.randint(32,126))+chr(random.randint(32,126))+chr(random.randint(32,126)))
for i in range(random.randint(2,7)):
  print(chr(random.randint(32,126)),end="")
string.degre = ["PHD","Master","Bachelor"]
print("\n"+random.choice(string.degre))
# Out:
# h
# Oo
# wRfhU
# r71Dd
# x,O|
# PHD
