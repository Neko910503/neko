# %% [markdown]
# # Analyzing a double hanger resonator (S Param)
# ### Prerequisite
# You must have a working local installation of Ansys.

# %%
# %load_ext autoreload
# %autoreload 2

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
import pyEPR as epr

# %% [markdown]
# ## Create the design in Metal
# Set up a design of a given dimension. Dimensions will be respected in the design rendering.
# <br>
# Note the chip design is centered at origin (0,0).

# %%
design = designs.DesignPlanar({}, True)
design.chips.main.size['size_x'] = '2mm'
design.chips.main.size['size_y'] = '2mm'

gui = MetalGUI(design)

# %% [markdown]
# Perform the necessary imports.

# %%
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround

# %% [markdown]
# Add 2 transmons to the design.

# %%
options = dict(
    # Some options we want to modify from the deafults
    # (see below for defaults)
    pad_width = '425 um', 
    pocket_height = '650um',
    # Adding 4 connectors (see below for defaults)
    connection_pads=dict( 
        a = dict(loc_W=+1,loc_H=+1), 
        b = dict(loc_W=-1,loc_H=+1, pad_height='30um'),
        c = dict(loc_W=+1,loc_H=-1, pad_width='200um'),
        d = dict(loc_W=-1,loc_H=-1, pad_height='50um')
    )
)

## Create 2 transmons

q1 = TransmonPocket(design, 'Q1', options = dict(
    pos_x='+1.4mm', pos_y='0mm', orientation = '90', **options))
q2 = TransmonPocket(design, 'Q2', options = dict(
    pos_x='-0.6mm', pos_y='0mm', orientation = '90', **options))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# Add 2 hangers consisting of capacitively coupled transmission lines.

# %%
TQ1 = CoupledLineTee(design, 'TQ1', options=dict(pos_x='1mm',
                                             pos_y='3mm',
                                             coupling_length='200um'))
TQ2 = CoupledLineTee(design, 'TQ2', options=dict(pos_x='-1mm',
                                             pos_y='3mm',
                                             coupling_length='200um'))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# Add 2 meandered CPWs connecting the transmons to the hangers.

# %%
ops=dict(fillet='90um')
design.overwrite_enabled = True

options1 = Dict(
    total_length='8mm',
    hfss_wire_bonds = True,
    pin_inputs=Dict(
        start_pin=Dict(
            component='TQ1',
            pin='second_end'),
        end_pin=Dict(
            component='Q1',
            pin='a')),
    lead=Dict(
        start_straight='0.1mm'),
    **ops
)

options2 = Dict(
    total_length='9mm',
    hfss_wire_bonds = True,
    pin_inputs=Dict(
        start_pin=Dict(
            component='TQ2',
            pin='second_end'),
        end_pin=Dict(
            component='Q2',
            pin='a')),
    lead=Dict(
        start_straight='0.1mm'),
    **ops
)

meanderQ1 = RouteMeander(design, 'meanderQ1', options=options1)
meanderQ2 = RouteMeander(design, 'meanderQ2', options=options2)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# Add 2 open to grounds at the ends of the horizontal CPW.

# %%
otg1 = OpenToGround(design, 'otg1', options = dict(pos_x='3mm', 
                                                   pos_y='3mm'))
otg2 = OpenToGround(design, 'otg2', options = dict(pos_x = '-3mm', 
                                                   pos_y='3mm', 
                                                   orientation='180'))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# Add 3 straight CPWs that comprise the long horizontal CPW.

# %%
ops_oR = Dict(hfss_wire_bonds = True,
              pin_inputs=Dict(
                 start_pin=Dict(
                     component='TQ1',
                     pin='prime_end'),
                 end_pin=Dict(
                     component='otg1',
                     pin='open')))
ops_mid = Dict(hfss_wire_bonds = True,
               pin_inputs=Dict(
                 start_pin=Dict(
                     component='TQ1',
                     pin='prime_start'),
                 end_pin=Dict(
                     component='TQ2',
                     pin='prime_end')))
ops_oL = Dict(hfss_wire_bonds = True,
              pin_inputs=Dict(
                 start_pin=Dict(
                     component='TQ2',
                     pin='prime_start'),
                 end_pin=Dict(
                     component='otg2',
                     pin='open')))

cpw_openRight = RouteStraight(design, 'cpw_openRight', options=ops_oR)
cpw_middle = RouteStraight(design, 'cpw_middle', options=ops_mid)
cpw_openLeft = RouteStraight(design, 'cpw_openLeft', options=ops_oL)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## 2. Eigenmode and Impedance analysis using the `advanced` flow
#
# If you are interested in the `recommended` flow, please check the tutorial notebook 4.3. In this section we will use the advanced flow, which directly operates on the simulator thorugh the renderer commands.
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses.simulation` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.simulation.scattering_impedance import ScatteringImpedanceSim
em1 = ScatteringImpedanceSim(design, "hfss")

# %% [markdown]
# For the DrivenModal simulation portion, you can either:
# 1. Use the `em1` user-friendly methods (see tutorial 4.3)
# 2. Control directly the simulation tool from the tool's GUI (outside metal - see specific vendor instructions)
# 3. Use the renderer methods
# In this section we show the advanced method (method 3).
#
# The renderer can be reached from the analysis class. Let's give it a shorter alias.

# %%
hfss = em1.renderer

# %% [markdown]
# Now we connect to the tool using the unified command.

# %%
hfss.start()
# Out:
# INFO 01:54PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 01:54PM [load_ansys_project]: 	Opened Ansys App
# INFO 01:54PM [load_ansys_project]: 	Opened Ansys Desktop v2023.1.0
# INFO 01:54PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/askev/OneDrive/文件/Ansoft/
# 	Project:   Project2
# INFO 01:54PM [connect_design]: 	Opened active design
# 	Design:    TransmonResonator_q3d [Solution type: Q3D]
# INFO 01:54PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 01:54PM [connect]: 	Connected to project "Project2" and design "TransmonResonator_q3d" 😀
# True

# %% [markdown]
# #### Execute simulation and verify convergence
#
# Create and activate an eigenmode design called "HangingResonators".

# %%
hfss.activate_ansys_design("HangingResonators", 'drivenmodal')
# Out:
# 01:54PM 13s WARNING [activate_ansys_design]: The design_name=HangingResonators was not in active project.  Designs in active project are:
# ['TransmonReadout', 'Readout_1', 'Readout', 'TransmonResonator_q3d'].  A new design will be added to the project.
# INFO 01:54PM [connect_design]: 	Opened active design
# 	Design:    HangingResonators [Solution type: HFSS Hybrid Modal Network]
# WARNING 01:54PM [connect_setup]: 	No design setup detected.
# ERROR 01:54PM [connect_setup]: Original error 😭: 'NoneType' object has no attribute 'name'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyEPR\project_info.py:335, in ProjectInfo.connect_setup(self)
#     334         setup = self.design.create_q3d_setup()
# --> 335     self.setup_name = setup.name
#     336 else:
#
# AttributeError: 'NoneType' object has no attribute 'name'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 hfss.activate_ansys_design("HangingResonators", 'drivenmodal')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:847, in QAnsysRenderer.activate_ansys_design(self, design_name, solution_type)
#     842 self.logger.warning(
#     843     f"The design_name={design_name} was not in active project.  "
#     844     f"Designs in active project are: \n{names_in_design}.  "
#     845     "A new design will be added to the project.  ")
#     846 if solution_type is not None:
# --> 847     adesign = self.new_ansys_design(
#     848         design_name=design_name,
#     849         solution_type=solution_type,
#     850         connect=True,
#     851     )
#     852 else:
#     853     self.logger.error(
#     854         "Please specify the solution_type, to determine what design to create"
#     855     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:794, in QAnsysRenderer.new_ansys_design(self, design_name, solution_type, connect)
#     792         raise
#     793     if connect:
# --> 794         self.connect_ansys_design(adesign.name)
#     795     return adesign
#     796 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:462, in QAnsysRenderer.connect_ansys_design(self, design_name)
#     460 try:
#     461     self.pinfo.connect_design(design_name)
# --> 462     self.pinfo.connect_setup()
#     463 except AttributeError:
#     464     self.logger.error(
#     465         "Please install a more recent version of pyEPR (>=0.8.4.3)"
#     466     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyEPR\project_info.py:346, in ProjectInfo.connect_setup(self)
#     344         _traceback = sys.exc_info()[2]
#     345         logger.error(f"Original error \N{loudly crying face}: {e}\n")
# --> 346         raise Exception(' Did you provide the correct setup name?\
#     347                     Failed to pull up setup. \N{loudly crying face}'
#     348                         ).with_traceback(_traceback)
#     350 else:
#     351     self.setup = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyEPR\project_info.py:335, in ProjectInfo.connect_setup(self)
#     333         logger.warning('\tCreating Q3D default setup.')
#     334         setup = self.design.create_q3d_setup()
# --> 335     self.setup_name = setup.name
#     336 else:
#     337     self.setup_name = setup_names[0]
#
# Exception:  Did you provide the correct setup name?                            Failed to pull up setup. 😭

# %% [markdown]
# Set the buffer width at the edge of the design to be 0.5 mm in both directions.

# %%
hfss.options['x_buffer_width_mm'] = 0.5
hfss.options['y_buffer_width_mm'] = 0.5

# %% [markdown]
# #### Execute simulation and observe the Impedence
# Assign lumped ports on the two cpw terminations. Then observe the impedance plots.
#
# Here, pins cpw_openRight_end and cpw_openLeft_end are converted into lumped ports with an impedance of 50 Ohms. <br>
# Neither of the junctions in Q1 or Q2 are rendered.

# %%
hfss.render_design(selection=[], 
                   open_pins=[], 
                   port_list=[('cpw_openRight', 'end', 50), ('cpw_openLeft', 'end', 50)], 
                   jj_to_port=[], 
                   ignored_jjs=[('Q1', 'rect_jj'), ('Q2', 'rect_jj')],
                   box_plus_buffer = True)

# %% [markdown]
# (optional) Captures the renderer GUI.

# %%
hfss.save_screenshot()
# Out:
# WindowsPath('C:/Users/askev/qiskit-metal/tutorials/4 Analysis/B. Advanced - Direct use of the renderers/ansys.png')

# %% [markdown]
# Create the frequency sweep to observe the impedance, admittance and scattering matrices.

# %%
hfss.add_sweep(setup_name="Setup", 
               name="Sweep", 
               start_ghz=4.0,
               stop_ghz=8.0,
               count=2001,
               type="Interpolating")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 hfss.add_sweep(setup_name="Setup",
#       2                name="Sweep",
#       3                start_ghz=4.0,
#       4                stop_ghz=8.0,
#       5                count=2001,
#       6                type="Interpolating")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py:875, in QHFSSRenderer.add_sweep(self, setup_name, start_ghz, stop_ghz, count, step_ghz, name, type, save_fields)
#     856 """Add a frequency sweep to a driven modal setup.
#     857
#     858 Args:
#    (...)
#     872                         Defaults to False.
#     873 """
#     874 if self.pinfo:
# --> 875     setup = self.pinfo.get_setup(setup_name)
#     876     return setup.insert_sweep(start_ghz=start_ghz,
#     877                               stop_ghz=stop_ghz,
#     878                               count=count,
#    (...)
#     881                               type=type,
#     882                               save_fields=save_fields)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyEPR\project_info.py:403, in ProjectInfo.get_setup(self, name)
#     401 if name is None:
#     402     return None
# --> 403 self.setup = self.design.get_setup(name=name)
#     404 if self.setup is None:
#     405     logger.error(f"Could not retrieve setup: {name}\n \
#     406                 Did you give the right name? Does it exist?")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyEPR\ansys.py:707, in HfssDesign.get_setup(self, name)
#     705 setups = self.get_setup_names()
#     706 if not setups:
# --> 707     raise EnvironmentError(" *** No Setups Present ***")
#     708 if name is None:
#     709     name = setups[0]
#
# OSError:  *** No Setups Present ***

# %%
hfss.analyze_sweep('Sweep', 'Setup')

# %% [markdown]
# Plot S, Y, and Z parameters as a function of frequency. <br>
# The left and right plots display the magnitude and phase, respectively.

# %%
hfss.plot_params(['S11', 'S21'])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hfss.plot_params(['S11', 'S21'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py:949, in QHFSSRenderer.plot_params(self, param_name)
#     942 def plot_params(self, param_name: Union[list, None] = None):
#     943     """Plot one or more parameters (S, Y, or Z) as a function of frequency.
#     944     S = scattering matrix, Y = Admittance, Z= impedance.
#     945
#     946     Args:
#     947         param_name (Union[list, None], optional): Parameters to plot. Defaults to None.
#     948     """
# --> 949     freqs, Pcurves, Pparams = self.get_params(param_name)
#     950     if Pparams is not None:
#     951         fig, axs = plt.subplots(1, 2, figsize=(10, 6))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py:909, in QHFSSRenderer.get_params(self, param_name)
#     905     freqs, Pcurves = self.current_sweep.get_network_data(param_name)
#     906     Pparams = pd.DataFrame(Pcurves,
#     907                            columns=freqs / 1e9,
#     908                            index=param_name).transpose()
# --> 909 return freqs, Pcurves, Pparams
#
# UnboundLocalError: local variable 'freqs' referenced before assignment

# %%
hfss.plot_params(['Y11', 'Y21'])

# %%
hfss.plot_params(['Z11', 'Z21'])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 hfss.plot_params(['Z11', 'Z21'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py:949, in QHFSSRenderer.plot_params(self, param_name)
#     942 def plot_params(self, param_name: Union[list, None] = None):
#     943     """Plot one or more parameters (S, Y, or Z) as a function of frequency.
#     944     S = scattering matrix, Y = Admittance, Z= impedance.
#     945
#     946     Args:
#     947         param_name (Union[list, None], optional): Parameters to plot. Defaults to None.
#     948     """
# --> 949     freqs, Pcurves, Pparams = self.get_params(param_name)
#     950     if Pparams is not None:
#     951         fig, axs = plt.subplots(1, 2, figsize=(10, 6))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\renderers\renderer_ansys\hfss_renderer.py:909, in QHFSSRenderer.get_params(self, param_name)
#     905     freqs, Pcurves = self.current_sweep.get_network_data(param_name)
#     906     Pparams = pd.DataFrame(Pcurves,
#     907                            columns=freqs / 1e9,
#     908                            index=param_name).transpose()
# --> 909 return freqs, Pcurves, Pparams
#
# UnboundLocalError: local variable 'freqs' referenced before assignment

# %% [markdown]
# Finally, disconnect from Ansys.

# %%
em1.close()

# %% [markdown]
# (optional) close the GUI.

# %%
# gui.main_window.close()
