# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from qiskit_metal.analyses.quantization.lumped_capacitive import load_q3d_capacitance_matrix
from qiskit_metal.analyses.quantization.lom_core_analysis import CompositeSystem, Cell, Subsystem 

from scipy.constants import speed_of_light as c_light

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 11:44PM 28s INFO [__init__]: TransmonBuilder with system_type TRANSMON registered to QuantumSystemRegistry
# 11:44PM 28s INFO [__init__]: FluxoniumBuilder with system_type FLUXONIUM registered to QuantumSystemRegistry
# 11:44PM 28s INFO [__init__]: TLResonatorBuilder with system_type TL_RESONATOR registered to QuantumSystemRegistry
# 11:44PM 28s INFO [__init__]: LumpedResonatorBuilder with system_type LUMPED_RESONATOR registered to QuantumSystemRegistry

# %% [markdown]
# # Example: two transmons coupled by a direct coupler
# this part is identical to tutorial 4.05; please reference it for more detailed comments

# %% [markdown]
# ### load transmon cell Q3d simulation results

# %%
path1 = './Q1_TwoTransmon_CapMatrix.txt'
ta_mat, _, _, _ = load_q3d_capacitance_matrix(path1)
# Out:
# Imported capacitance matrix with UNITS: [fF] now converted to USER UNITS:[fF]                 from file:
# 	./Q1_TwoTransmon_CapMatrix.txt
# <style type="text/css">
# #T_185aa_row0_col0, #T_185aa_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.6%, #5fba7d 38.6%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_185aa_row0_col1, #T_185aa_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.9%, #5fba7d 0.9%, #5fba7d 13.9%, transparent 13.9%);
# }
# #T_185aa_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.4%, #5fba7d 28.4%, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.6%, #5fba7d 15.6%, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row0_col4, #T_185aa_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.4%, #5fba7d 38.4%, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row1_col0, #T_185aa_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.9%, #5fba7d 13.9%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_185aa_row1_col2, #T_185aa_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.6%, #5fba7d 36.6%, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #5fba7d 0.0%, #5fba7d 13.9%, transparent 13.9%);
# }
# #T_185aa_row2_col2, #T_185aa_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.0%, #5fba7d 30.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_185aa_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 7.0%, #5fba7d 7.0%, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.7%, #5fba7d 18.7%, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.8%, #5fba7d 18.8%, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 13.9%, transparent 13.9%);
# }
# #T_185aa_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.9%, #5fba7d 6.9%, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.5%, #5fba7d 36.5%, #5fba7d 38.6%, transparent 38.6%);
# }
# #T_185aa_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.5%, #5fba7d 15.5%, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_185aa_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.5%, #5fba7d 28.5%, #5fba7d 30.0%, transparent 30.0%);
# }
# </style>
# <table id="T_185aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_185aa_level0_col0" class="col_heading level0 col0" >coupler_connector_pad_Q1</th>
#       <th id="T_185aa_level0_col1" class="col_heading level0 col1" >ground_main_plane</th>
#       <th id="T_185aa_level0_col2" class="col_heading level0 col2" >pad_bot_Q1</th>
#       <th id="T_185aa_level0_col3" class="col_heading level0 col3" >pad_top_Q1</th>
#       <th id="T_185aa_level0_col4" class="col_heading level0 col4" >readout_connector_pad_Q1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_185aa_level0_row0" class="row_heading level0 row0" >coupler_connector_pad_Q1</th>
#       <td id="T_185aa_row0_col0" class="data row0 col0" >59.20</td>
#       <td id="T_185aa_row0_col1" class="data row0 col1" >-37.28</td>
#       <td id="T_185aa_row0_col2" class="data row0 col2" >-2.01</td>
#       <td id="T_185aa_row0_col3" class="data row0 col3" >-19.11</td>
#       <td id="T_185aa_row0_col4" class="data row0 col4" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_185aa_level0_row1" class="row_heading level0 row1" >ground_main_plane</th>
#       <td id="T_185aa_row1_col0" class="data row1 col0" >-37.28</td>
#       <td id="T_185aa_row1_col1" class="data row1 col1" >246.33</td>
#       <td id="T_185aa_row1_col2" class="data row1 col2" >-39.79</td>
#       <td id="T_185aa_row1_col3" class="data row1 col3" >-39.86</td>
#       <td id="T_185aa_row1_col4" class="data row1 col4" >-37.30</td>
#     </tr>
#     <tr>
#       <th id="T_185aa_level0_row2" class="row_heading level0 row2" >pad_bot_Q1</th>
#       <td id="T_185aa_row2_col0" class="data row2 col0" >-2.01</td>
#       <td id="T_185aa_row2_col1" class="data row2 col1" >-39.79</td>
#       <td id="T_185aa_row2_col2" class="data row2 col2" >93.05</td>
#       <td id="T_185aa_row2_col3" class="data row2 col3" >-30.61</td>
#       <td id="T_185aa_row2_col4" class="data row2 col4" >-19.22</td>
#     </tr>
#     <tr>
#       <th id="T_185aa_level0_row3" class="row_heading level0 row3" >pad_top_Q1</th>
#       <td id="T_185aa_row3_col0" class="data row3 col0" >-19.11</td>
#       <td id="T_185aa_row3_col1" class="data row3 col1" >-39.86</td>
#       <td id="T_185aa_row3_col2" class="data row3 col2" >-30.61</td>
#       <td id="T_185aa_row3_col3" class="data row3 col3" >92.99</td>
#       <td id="T_185aa_row3_col4" class="data row3 col4" >-2.01</td>
#     </tr>
#     <tr>
#       <th id="T_185aa_level0_row4" class="row_heading level0 row4" >readout_connector_pad_Q1</th>
#       <td id="T_185aa_row4_col0" class="data row4 col0" >-0.23</td>
#       <td id="T_185aa_row4_col1" class="data row4 col1" >-37.30</td>
#       <td id="T_185aa_row4_col2" class="data row4 col2" >-19.22</td>
#       <td id="T_185aa_row4_col3" class="data row4 col3" >-2.01</td>
#       <td id="T_185aa_row4_col4" class="data row4 col4" >59.33</td>
#     </tr>
#   </tbody>
# </table>

# %%
path2 = './Q2_TwoTransmon_CapMatrix.txt'
tb_mat, _, _, _ = load_q3d_capacitance_matrix(path2)
# Out:
# Imported capacitance matrix with UNITS: [fF] now converted to USER UNITS:[fF]                 from file:
# 	./Q2_TwoTransmon_CapMatrix.txt
# <style type="text/css">
# #T_2cf63_row0_col0, #T_2cf63_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.4%, #5fba7d 37.4%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_2cf63_row0_col1, #T_2cf63_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, #5fba7d 3.4%, #5fba7d 15.6%, transparent 15.6%);
# }
# #T_2cf63_row0_col2, #T_2cf63_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.6%, #5fba7d 27.6%, #5fba7d 28.9%, transparent 28.9%);
# }
# #T_2cf63_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.5%, #5fba7d 15.5%, #5fba7d 28.9%, transparent 28.9%);
# }
# #T_2cf63_row0_col4, #T_2cf63_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.2%, #5fba7d 37.2%, #5fba7d 37.4%, transparent 37.4%);
# }
# #T_2cf63_row1_col0, #T_2cf63_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 37.4%, transparent 37.4%);
# }
# #T_2cf63_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.6%, #5fba7d 15.6%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_2cf63_row1_col2, #T_2cf63_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 28.9%, transparent 28.9%);
# }
# #T_2cf63_row2_col0, #T_2cf63_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.3%, #5fba7d 35.3%, #5fba7d 37.4%, transparent 37.4%);
# }
# #T_2cf63_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #5fba7d 0.0%, #5fba7d 15.6%, transparent 15.6%);
# }
# #T_2cf63_row2_col2, #T_2cf63_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.9%, #5fba7d 28.9%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_2cf63_row2_col3, #T_2cf63_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.4%, #5fba7d 2.4%, #5fba7d 28.9%, transparent 28.9%);
# }
# #T_2cf63_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.1%, #5fba7d 15.1%, #5fba7d 37.4%, transparent 37.4%);
# }
# #T_2cf63_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, #5fba7d 15.2%, #5fba7d 37.4%, transparent 37.4%);
# }
# #T_2cf63_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 15.6%, transparent 15.6%);
# }
# #T_2cf63_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.4%, #5fba7d 15.4%, #5fba7d 28.9%, transparent 28.9%);
# }
# </style>
# <table id="T_2cf63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cf63_level0_col0" class="col_heading level0 col0" >coupler_connector_pad_Q2</th>
#       <th id="T_2cf63_level0_col1" class="col_heading level0 col1" >ground_main_plane</th>
#       <th id="T_2cf63_level0_col2" class="col_heading level0 col2" >pad_bot_Q2</th>
#       <th id="T_2cf63_level0_col3" class="col_heading level0 col3" >pad_top_Q2</th>
#       <th id="T_2cf63_level0_col4" class="col_heading level0 col4" >readout_connector_pad_Q2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cf63_level0_row0" class="row_heading level0 row0" >coupler_connector_pad_Q2</th>
#       <td id="T_2cf63_row0_col0" class="data row0 col0" >64.52</td>
#       <td id="T_2cf63_row0_col1" class="data row0 col1" >-38.63</td>
#       <td id="T_2cf63_row0_col2" class="data row0 col2" >-2.18</td>
#       <td id="T_2cf63_row0_col3" class="data row0 col3" >-22.93</td>
#       <td id="T_2cf63_row0_col4" class="data row0 col4" >-0.22</td>
#     </tr>
#     <tr>
#       <th id="T_2cf63_level0_row1" class="row_heading level0 row1" >ground_main_plane</th>
#       <td id="T_2cf63_row1_col0" class="data row1 col0" >-38.63</td>
#       <td id="T_2cf63_row1_col1" class="data row1 col1" >267.40</td>
#       <td id="T_2cf63_row1_col2" class="data row1 col2" >-49.28</td>
#       <td id="T_2cf63_row1_col3" class="data row1 col3" >-49.30</td>
#       <td id="T_2cf63_row1_col4" class="data row1 col4" >-38.67</td>
#     </tr>
#     <tr>
#       <th id="T_2cf63_level0_row2" class="row_heading level0 row2" >pad_bot_Q2</th>
#       <td id="T_2cf63_row2_col0" class="data row2 col0" >-2.18</td>
#       <td id="T_2cf63_row2_col1" class="data row2 col1" >-49.28</td>
#       <td id="T_2cf63_row2_col2" class="data row2 col2" >121.38</td>
#       <td id="T_2cf63_row2_col3" class="data row2 col3" >-45.24</td>
#       <td id="T_2cf63_row2_col4" class="data row2 col4" >-23.06</td>
#     </tr>
#     <tr>
#       <th id="T_2cf63_level0_row3" class="row_heading level0 row3" >pad_top_Q2</th>
#       <td id="T_2cf63_row3_col0" class="data row3 col0" >-22.93</td>
#       <td id="T_2cf63_row3_col1" class="data row3 col1" >-49.30</td>
#       <td id="T_2cf63_row3_col2" class="data row3 col2" >-45.24</td>
#       <td id="T_2cf63_row3_col3" class="data row3 col3" >121.24</td>
#       <td id="T_2cf63_row3_col4" class="data row3 col4" >-2.18</td>
#     </tr>
#     <tr>
#       <th id="T_2cf63_level0_row4" class="row_heading level0 row4" >readout_connector_pad_Q2</th>
#       <td id="T_2cf63_row4_col0" class="data row4 col0" >-0.22</td>
#       <td id="T_2cf63_row4_col1" class="data row4 col1" >-38.67</td>
#       <td id="T_2cf63_row4_col2" class="data row4 col2" >-23.06</td>
#       <td id="T_2cf63_row4_col3" class="data row4 col3" >-2.18</td>
#       <td id="T_2cf63_row4_col4" class="data row4 col4" >64.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Create LOM cells from capacitance matrices

# %%
# cell 1: transmon Alice cell

opt1 = dict(
    node_rename = {'coupler_connector_pad_Q1': 'coupling', 'readout_connector_pad_Q1': 'readout_alice'}, 
    cap_mat = ta_mat,
    ind_dict = {('pad_top_Q1', 'pad_bot_Q1'):10},  # junction inductance in nH
    jj_dict = {('pad_top_Q1', 'pad_bot_Q1'):'j1'},
    cj_dict = {('pad_top_Q1', 'pad_bot_Q1'):2}, # junction capacitance in fF

)
cell_1 = Cell(opt1)


# cell 2: transmon Bob cell
opt2 = dict(
    node_rename = {'coupler_connector_pad_Q2': 'coupling', 'readout_connector_pad_Q2': 'readout_bob'},
    cap_mat = tb_mat,
    ind_dict = {('pad_top_Q2', 'pad_bot_Q2'): 12}, # junction inductance in nH
    jj_dict = {('pad_top_Q2', 'pad_bot_Q2'):'j2'},
    cj_dict = {('pad_top_Q2', 'pad_bot_Q2'):2}, # junction capacitance in fF

)
cell_2 = Cell(opt2)

# %% [markdown]
# ### Make subsystems

# %%
# subsystem 1: transmon Alice
transmon_alice = Subsystem(name='transmon_alice', sys_type='TRANSMON', nodes=['j1'])


# subsystem 2: transmon Bob
transmon_bob = Subsystem(name='transmon_bob', sys_type='TRANSMON', nodes=['j2'])


# subsystem 3: Alice readout resonator
q_opts = dict(
    f_res = 8, # resonator dressed frequency in GHz
    Z0 = 50, # characteristic impedance in Ohm
    vp = 0.404314 * c_light # phase velocity 
)
res_alice = Subsystem(name='readout_alice', sys_type='TL_RESONATOR', nodes=['readout_alice'], q_opts=q_opts)


# subsystem 4: Bob readout resonator
q_opts = dict(
    f_res = 7.6, # resonator dressed frequency in GHz
    Z0 = 50, # characteristic impedance in Ohm
    vp = 0.404314 * c_light # phase velocity 
)
res_bob = Subsystem(name='readout_bob', sys_type='TL_RESONATOR', nodes=['readout_bob'], q_opts=q_opts)

# %% [markdown]
# ### Creat the composite system from the cells and the subsystems

# %%
composite_sys = CompositeSystem(
    subsystems=[transmon_alice, transmon_bob, res_alice, res_bob], 
    cells=[cell_1, cell_2], 
    grd_node='ground_main_plane',
    nodes_force_keep=['readout_alice', 'readout_bob']
)

# %%
cg = composite_sys.circuitGraph()
print(cg)
# Out:
# node_jj_basis:
# -------------
#
# ['j1', 'pad_bot_Q1', 'j2', 'pad_bot_Q2', 'readout_alice', 'readout_bob', 'coupling']
#
# nodes_keep:
# -------------
#
# ['j1', 'j2', 'readout_alice', 'readout_bob']
#
#
# L_inv_k (reduced inverse inductance matrix):
# -------------
#
#                 j1        j2  readout_alice  readout_bob
# j1             0.1  0.000000            0.0          0.0
# j2             0.0  0.083333            0.0          0.0
# readout_alice  0.0  0.000000            0.0          0.0
# readout_bob    0.0  0.000000            0.0          0.0
#
# C_k (reduced capacitance matrix):
# -------------
#
#                       j1         j2  readout_alice  readout_bob
# j1             63.185549  -0.766012       8.318893    -0.323188
# j2             -0.766012  84.343548      -0.342145    10.039921
# readout_alice   8.318893  -0.342145      55.591197    -0.144354
# readout_bob    -0.323188  10.039921      -0.144354    60.347427

# %% [markdown]
# ### Generate the hilberspace from the composite system, leveraging the scqubits package

# %%
hilbertspace = composite_sys.create_hilbertspace()
hilbertspace = composite_sys.add_interaction()
hilbertspace.hamiltonian()
# Out:
# WARNING:py.warnings:RuntimeWarning: divide by zero encountered in double_scalars
#  C:\Users\askev\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\analyses\quantization\lom_core_analysis.py: 170
# WARNING:py.warnings:RuntimeWarning: divide by zero encountered in double_scalars
#  C:\Users\askev\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\analyses\quantization\lom_core_analysis.py: 170
# WARNING:py.warnings:RuntimeWarning: divide by zero encountered in double_scalars
#  C:\Users\askev\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\analyses\quantization\lom_core_analysis.py: 170
# WARNING:py.warnings:RuntimeWarning: divide by zero encountered in double_scalars
#  C:\Users\askev\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit_metal\analyses\quantization\lom_core_analysis.py: 170
# Quantum object: dims = [[10, 10, 3, 3], [10, 10, 3, 3]], shape = (900, 900), type = oper, isherm = True
# Qobj data =
# [[-24384.00898603+0.00000000e+00j      0.        +1.08232559e-01j
#        0.        +0.00000000e+00j ...      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j      0.        +0.00000000e+00j]
#  [     0.        -1.08232559e-01j -16784.00898603+0.00000000e+00j
#        0.        +1.53063953e-01j ...      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j      0.        +0.00000000e+00j]
#  [     0.        +0.00000000e+00j      0.        -1.53063953e-01j
#    -9184.00898603+0.00000000e+00j ...      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j      0.        +0.00000000e+00j]
#  ...
#  [     0.        +0.00000000e+00j      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j ...  73269.11342615+0.00000000e+00j
#        0.        +4.99608155e+02j      0.        +0.00000000e+00j]
#  [     0.        +0.00000000e+00j      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j ...      0.        -4.99608155e+02j
#    80869.11342615+0.00000000e+00j      0.        +7.06552629e+02j]
#  [     0.        +0.00000000e+00j      0.        +0.00000000e+00j
#        0.        +0.00000000e+00j ...      0.        +0.00000000e+00j
#        0.        -7.06552629e+02j  88469.11342615+0.00000000e+00j]]

# %% [markdown]
# ### Print the results

# %%
hamiltonian_results = composite_sys.hamiltonian_results(hilbertspace, evals_count=30)
# Out:
# system frequencies in GHz:
# --------------------------
# {'transmon_alice': 6.053360688806889, 'transmon_bob': 4.798988322288846, 'readout_alice': 8.009054820710858, 'readout_bob': 7.604412010767002}
#
# Chi matrices in MHz
# --------------------------
#                 transmon_alice  transmon_bob  readout_alice  readout_bob
# transmon_alice     -353.239816     -0.542895      -4.132854    -0.003120
# transmon_bob         -0.542895   -263.940098      -0.001154    -1.460416
# readout_alice        -4.132854     -0.001154       4.283111    -0.000017
# readout_bob          -0.003120     -1.460416      -0.000017     3.829744

# %%
hamiltonian_results['chi_in_MHz'].to_dataframe()
# Out:
#                 transmon_alice  transmon_bob  readout_alice  readout_bob
# transmon_alice     -353.239816     -0.542895      -4.132854    -0.003120
# transmon_bob         -0.542895   -263.940098      -0.001154    -1.460416
# readout_alice        -4.132854     -0.001154       4.283111    -0.000017
# readout_bob          -0.003120     -1.460416      -0.000017     3.829744

# %%
composite_sys.compute_gs()
# Out:
#                        j1          j2  readout_alice  readout_bob
# j1               0.000000   20.115410    -129.897537     3.275638
# j2              20.115410    0.000000       2.678608  -111.508230
# readout_alice -129.897537    2.678608       0.000000     0.436190
# readout_bob      3.275638 -111.508230       0.436190     0.000000

# %%
transmon_alice.h_params
# Out:
# defaultdict(dict,
#             {'j1': {'EJ': 16346.15128067812,
#               'EC': 312.756868730393,
#               'Q_zpf': 3.204353268e-19,
#               'default_charge_op': Operator(op=array([[-22,   0,   0, ...,   0,   0,   0],
#                      [  0, -21,   0, ...,   0,   0,   0],
#                      [  0,   0, -20, ...,   0,   0,   0],
#                      ...,
#                      [  0,   0,   0, ...,  20,   0,   0],
#                      [  0,   0,   0, ...,   0,  21,   0],
#                      [  0,   0,   0, ...,   0,   0,  22]]), add_hc=False)}})

# %%
transmon_bob.h_params
# Out:
# defaultdict(dict,
#             {'j2': {'EJ': 13621.792733898432,
#               'EC': 234.3240926996763,
#               'Q_zpf': 3.204353268e-19,
#               'default_charge_op': Operator(op=array([[-22,   0,   0, ...,   0,   0,   0],
#                      [  0, -21,   0, ...,   0,   0,   0],
#                      [  0,   0, -20, ...,   0,   0,   0],
#                      ...,
#                      [  0,   0,   0, ...,  20,   0,   0],
#                      [  0,   0,   0, ...,   0,  21,   0],
#                      [  0,   0,   0, ...,   0,   0,  22]]), add_hc=False)}})

# %% [markdown]
# ### ***********

# %% [markdown]
# ## Time evolution simulation with Sequencing https://sequencing.readthedocs.io/en/latest/index.html

# %%
# %config InlineBackend.figure_formats = ['svg']

import qutip
from tqdm import tqdm

from sequencing import get_sequence, sync
from sequencing.calibration import tune_rabi

from qiskit_metal.analyses.quantization.lom_time_evolution_sim import lom_composite_sys_to_seq_sys
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 6
#       3 import qutip
#       4 from tqdm import tqdm
# ----> 6 from sequencing import get_sequence, sync
#       7 from sequencing.calibration import tune_rabi
#       9 from qiskit_metal.analyses.quantization.lom_time_evolution_sim import lom_composite_sys_to_seq_sys
#
# File ~\AppData\Local\Programs\Python\Python310\Lib\site-packages\shiboken2\files.dir\shibokensupport\__feature__.py:142, in _import(name, *args, **kwargs)
#     140     flag = -1
#     141 pyside_feature_dict[importing_module] = flag
# --> 142 return original_import(name, *args, **kwargs)
#
# ModuleNotFoundError: No module named 'sequencing'

# %% [markdown]
# ### A simple example: selective qubit pulse in the strong dispersive regime
#
# <img src="number_splitting.png" width=600 height=600 />
#
# \* *Dave Schuster's thesis* https://rsl.yale.edu/sites/default/files/files/RSL_Theses/SchusterThesis.pdf

# %% [markdown]
# #### LOM composite system to Sequencing system
#
# <img src="sequencing_h.png" width=600 height=600 />
#
# \* Sequencing documentation, https://sequencing.readthedocs.io/en/latest/notebooks/introduction.html
#
# In this part of the demo, we essentially **reproduce the exact same example as demonstrated in the Sequencing tutorial**, "Controlling a Transmon coupled to Cavity", https://sequencing.readthedocs.io/en/latest/notebooks/06-transmon-cavity-control.html, by generating a Sequencing system converted from a LOM composite system. Hence please follow the Sequencing tutorial for more detailed explanations on the pulse construction, calibration and ultimately simulation.

# %% [markdown]
# ##### Convert Metal LOM system to Sequencing system
# A Qiskit Metal LOM subsystem corresponds to a 'mode' in Sequencing system. The diagonal elements in `hamiltonian_results['chi_in_MHz']` (anharmonicity) are the self-Kerr's and the off-diagonal elements the cross-Kerr's in Sequencing's Hamiltonian screenshot above.
#
# For more details on modes in Sequencing system, please check out the Sequencing package's documentation. The `levels` parameter specifies the number of energy levels to keep for each mode in the Sequencing system. If not specified, i.e., None, they default to LOM subsystem's respective dimensions as represented by the LOM composite system's hilberspace (`hilbertspace.subsystem_dims`)

# %%
system = lom_composite_sys_to_seq_sys(composite_sys, hilbertspace, levels=[3, 3, 10, 10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 system = lom_composite_sys_to_seq_sys(composite_sys, hilbertspace, levels=[3, 3, 10, 10])
#
# NameError: name 'lom_composite_sys_to_seq_sys' is not defined

# %%
alice = system.modes[1]
readout_alice = system.modes[-1]
print(alice)
print(readout_alice)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 alice = system.modes[1]
#       2 readout_alice = system.modes[-1]
#       3 print(alice)
#
# NameError: name 'system' is not defined

# %% [markdown]
# ### Are there zero photon in the cavity?
#
# #### Tune the amplitude of a pulse on Alice using an amplitude-Rabi sequence

# %%
selective_sigma = 100 # ns

# tune selective qubit pulse using Rabi
with system.use_modes([alice]):
    with alice.temporarily_set(gaussian_pulse__sigma=selective_sigma):
        _, _, selective_qubit_amp = tune_rabi(
            system, system.fock(transmon_alice=0, transmon_bob=0, readout_alice=0, readout_bob=0), mode_name=alice.name, update=False, plot=True, verify=False
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 selective_sigma = 100 # ns
#       3 # tune selective qubit pulse using Rabi
# ----> 4 with system.use_modes([alice]):
#       5     with alice.temporarily_set(gaussian_pulse__sigma=selective_sigma):
#       6         _, _, selective_qubit_amp = tune_rabi(
#       7             system, system.fock(transmon_alice=0, transmon_bob=0, readout_alice=0, readout_bob=0), mode_name=alice.name, update=False, plot=True, verify=False
#       8         )
#
# NameError: name 'system' is not defined

# %%
def selective_rotation(qubit, angle, phase=0, detune=0, sigma=selective_sigma):
    with qubit.gaussian_pulse.temporarily_set(sigma=sigma, amp=selective_qubit_amp):
         qubit.rotate(np.pi, phase, detune=detune)

# %% [markdown]
# #### Populate alice readout cavity with 0, 1, 2, 3 photons respectively

# %%
init_states = [
    (f'$|g{n}\\rangle$', system.fock(transmon_alice=0, readout_alice=n)) for n in range(4)
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 init_states = [
#       2     (f'$|g{n}\\rangle$', system.fock(transmon_alice=0, readout_alice=n)) for n in range(4)
#       3 ]
#
# Cell In[19], line 2, in <listcomp>(.0)
#       1 init_states = [
# ----> 2     (f'$|g{n}\\rangle$', system.fock(transmon_alice=0, readout_alice=n)) for n in range(4)
#       3 ]
#
# NameError: name 'system' is not defined

# %%
# Apply a selective pi pulse that is resonant
# with the qubit when the cavity is in |0>.
results = {}

seq = get_sequence(system)
selective_rotation(alice, np.pi)

for label, state in tqdm(init_states, desc='Initial states'):
    result = seq.run(state)
    results[label] = result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 # Apply a selective pi pulse that is resonant
#       2 # with the qubit when the cavity is in |0>.
#       3 results = {}
# ----> 5 seq = get_sequence(system)
#       6 selective_rotation(alice, np.pi)
#       8 for label, state in tqdm(init_states, desc='Initial states'):
#
# NameError: name 'get_sequence' is not defined

# %%
fig, ax = plt.subplots(1, 1)
for label, result in results.items():
    # trace over the cavity
    qubit_states = [state.ptrace(alice.index) for state in result.states]
    e_pops = qutip.expect(alice.fock_dm(1, full_space=False), qubit_states)
    ax.plot(result.times, e_pops, label=label)
    ax.grid(True)
    ax.legend(loc=0)
ax.set_xlabel('Time [ns]')
ax.set_ylabel(r'$P(|e\rangle)$')
_ = ax.set_title('Transmon trajectory vs. initial cavity state')

# %% [markdown]
# #### Use the qubit to measure the cavity: how many photons are there?

# %%
def rotate_qubit_on_n(system, n, angle, qubit_name='transmon_alice', cavity_name='readout_alice'):
    """Rotate the qubit state iff the cavity is in state |n> by detuning
    the selective qubit pulse by n * chi.
    """
    qubit = system.get_mode(qubit_name)
    cavity = system.get_mode(cavity_name)
    chi = system.cross_kerrs[frozenset([qubit.name, cavity.name])]
    selective_rotation(qubit, angle, detune=n*chi)

# %% [markdown]
# ##### Displace the cavity and then apply selective pulse on alice

# %%
max_n = 4

init_state = system.ground_state()
# qubit in |e> after selective pi pulse means cavity in |n>
e_op = alice.fock_dm(1, full_space=False)
disp_amps = np.linspace(0.01, 3, 21)
e_pops = []

for n in range(max_n):
    e_pops.append([])
    for amp in tqdm(disp_amps, desc=f'Disp. amp. (measure n={n})'):
        seq = get_sequence(system)

        readout_alice.displace(amp)
        sync()
        rotate_qubit_on_n(system, n, np.pi)
        result = seq.run(init_state)
        # trace over the cavity
        transmon_state = result.states[-1].ptrace(alice.index)
        e_pops[-1].append(qutip.expect(e_op, transmon_state))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 max_n = 4
# ----> 3 init_state = system.ground_state()
#       4 # qubit in |e> after selective pi pulse means cavity in |n>
#       5 e_op = alice.fock_dm(1, full_space=False)
#
# NameError: name 'system' is not defined

# %%
fig, ax = plt.subplots()
for n, es in enumerate(e_pops):
    ax.plot(disp_amps, es, '.-', label=f'measure n = {n}')
ax.legend(loc=0)
ax.grid(True)
ax.set_xlabel('Displacement amplitude')
ax.set_ylabel(r'$P(|e\rangle)$')
_ = ax.set_title(r'Displacement sequence with selective $\pi$ pulse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 for n, es in enumerate(e_pops):
#       3     ax.plot(disp_amps, es, '.-', label=f'measure n = {n}')
#       4 ax.legend(loc=0)
#
# NameError: name 'e_pops' is not defined
